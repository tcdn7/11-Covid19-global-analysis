# %% [markdown]
# # COVID-19 Global Analysis – Data Cleaning & Feature Engineering
#
# This notebook builds a cleaned and feature-enriched version of the OWID COVID-19 dataset.

# %%
import sys
from pathlib import Path

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

plt.rcParams["figure.figsize"] = (12, 6)
plt.rcParams["axes.grid"] = True

# %%
ROOT_DIR = Path.cwd().parent
if str(ROOT_DIR) not in sys.path:
    sys.path.append(str(ROOT_DIR))

from src.config import COVID_RAW_PATH, PROCESSED_DATA_DIR, COVID_CLEAN_FEATURES_PATH
from src.data_loading import load_covid_data
from src.preprocessing import build_clean_feature_dataset

# %%
df_raw = load_covid_data()
print("Raw dataset loaded.")
print(f"Raw shape: {df_raw.shape[0]:,} rows x {df_raw.shape[1]} columns")
# Out:
# Raw dataset loaded.
# Raw shape: 166,326 rows x 67 columns

# %%
df_clean = build_clean_feature_dataset(df_raw)

print("Clean + feature-enriched dataset built.")
print(f"Clean shape: {df_clean.shape[0]:,} rows x {df_clean.shape[1]} columns")

df_clean.head()
# Out:
# Clean + feature-enriched dataset built.
# Clean shape: 155,331 rows x 72 columns
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan 2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan 2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan 2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan 2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan 2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    human_development_index  excess_mortality_cumulative_absolute  \
# 0                    0.511                                   NaN
# 1                    0.511                                   NaN
# 2                    0.511                                   NaN
# 3                    0.511                                   NaN
# 4                    0.511                                   NaN
#
#    excess_mortality_cumulative  excess_mortality  \
# 0                          NaN               NaN
# 1                          NaN               NaN
# 2                          NaN               NaN
# 3                          NaN               NaN
# 4                          NaN               NaN
#
#    excess_mortality_cumulative_per_million  new_cases_pm_7d_avg  \
# 0                                      NaN                  NaN
# 1                                      NaN                  NaN
# 2                                      NaN               0.0420
# 3                                      NaN               0.0315
# 4                                      NaN               0.0252
#
#    new_deaths_pm_7d_avg  stringency_index_7d_avg  case_fatality_ratio  \
# 0                   NaN                      NaN                  NaN
# 1                   NaN                      NaN                  NaN
# 2                   NaN                     8.33                  NaN
# 3                   NaN                     8.33                  NaN
# 4                   NaN                     8.33                  NaN
#
#    vaccination_coverage
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#
# [5 rows x 72 columns]

# %%
cols_to_inspect = [
    "location",
    "date",
    "new_cases_per_million",
    "new_cases_pm_7d_avg",
    "new_deaths_per_million",
    "new_deaths_pm_7d_avg",
    "case_fatality_ratio",
    "vaccination_coverage",
]

existing_cols = [c for c in cols_to_inspect if c in df_clean.columns]

df_clean[existing_cols].head(10)
# Out:
#       location       date  new_cases_per_million  new_cases_pm_7d_avg  \
# 0  Afghanistan 2020-02-24                  0.126                  NaN
# 1  Afghanistan 2020-02-25                  0.000                  NaN
# 2  Afghanistan 2020-02-26                  0.000               0.0420
# 3  Afghanistan 2020-02-27                  0.000               0.0315
# 4  Afghanistan 2020-02-28                  0.000               0.0252
# 5  Afghanistan 2020-02-29                  0.000               0.0210
# 6  Afghanistan 2020-03-01                  0.000               0.0180
# 7  Afghanistan 2020-03-02                  0.000               0.0000
# 8  Afghanistan 2020-03-03                  0.000               0.0000
# 9  Afghanistan 2020-03-04                  0.000               0.0000
#
#    new_deaths_per_million  new_deaths_pm_7d_avg  case_fatality_ratio  \
# 0                     NaN                   NaN                  NaN
# 1                     NaN                   NaN                  NaN
# 2                     NaN                   NaN                  NaN
# 3                     NaN                   NaN                  NaN
# 4                     NaN                   NaN                  NaN
# 5                     NaN                   NaN                  NaN
# 6                     NaN                   NaN                  NaN
# 7                     NaN                   NaN                  NaN
# 8                     NaN                   NaN                  NaN
# 9                     NaN                   NaN                  NaN
#
#    vaccination_coverage
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN

# %%
PROCESSED_DATA_DIR.mkdir(parents=True, exist_ok=True)

output_path = COVID_CLEAN_FEATURES_PATH
df_clean.to_csv(output_path, index=False)

print(f"Clean dataset with features saved to: {output_path}")
# Out:
# Clean dataset with features saved to: C:\Users\tcdn\Desktop\Projects\11-covid19-global-analysis\data\processed\covid19_clean_features.csv
